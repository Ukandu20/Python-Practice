# %%
from statsbombpy import sb

sb.competitions()
# Out:
# C:\Users\oukan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# ...

# %%
df=sb.matches(competition_id=43,  season_id=3)
# Out:
# C:\Users\oukan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
df[df.competition_stage=='Round of 16']
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 14      7580  2018-06-30  16:00:00.000  International - FIFA World Cup   2018
# 16      7581  2018-07-01  20:00:00.000  International - FIFA World Cup   2018
# 26      7583  2018-07-02  16:00:00.000  International - FIFA World Cup   2018
# 29      7584  2018-07-02  20:00:00.000  International - FIFA World Cup   2018
# 35      7582  2018-07-01  16:00:00.000  International - FIFA World Cup   2018
# 41      7579  2018-06-30  20:00:00.000  International - FIFA World Cup   2018
# 51      7585  2018-07-03  20:00:00.000  International - FIFA World Cup   2018
# 52      7586  2018-07-03  16:00:00.000  International - FIFA World Cup   2018
#
#    home_team    away_team  home_score  away_score match_status  ...  \
# 14    France    Argentina           4           3    available  ...
# 16   Croatia      Denmark           1           1    available  ...
# ...

# %%
sb.lineups(match_id=7584)
# Out:
# C:\Users\oukan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# {'Belgium':     player_id                 player_name    player_nickname  jersey_number  \
#  0        3077              Jan Vertonghen               None              5
#  1        3089             Kevin De Bruyne               None              7
#  2        3101             Vincent Kompany               None              4
#  3        3176              Thomas Meunier               None             15
#  4        3289        Romelu Lukaku Menama      Romelu Lukaku              9
#  5        3296  Marouane Fellaini-Bakkioui  Marouane Fellaini              8
#  6        3509            Thibaut Courtois               None              1
#  7        3621                 Eden Hazard               None             10
# ...
