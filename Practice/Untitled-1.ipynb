# %%
import pandas as pd
from scipy.stats import binom
import matplotlib.pyplot as plt

d = pd.read_csv("C:/Users/oukan/OneDrive/Documents/Personal Projects/Python/samplee.csv")

# %%
d.T
# Out:
#                                0               1          2              3    \
# Player           Patrick Mahomes*+  Justin Herbert  Tom Brady  Kirk Cousins*
# Tm                             KAN             LAC        TAM            MIN
# Age                             27              24         45             34
# Pos                             QB              QB         QB             QB
# Games_G                         17              17         17             17
# Games_GS                        17              17         17             17
# Passing_Cmp                    435             477        490            424
# Passing_Att                    648             699        733            643
# Passing_Yds                   5250            4739       4694           4547
# Passing_IAY                   4686            4476       4876           4800
# Passing_IAY/PA                 7.2             6.4        6.7            7.5
# ...

# %%
d.transpose()
# Out:
#                                0               1          2              3    \
# Player           Patrick Mahomes*+  Justin Herbert  Tom Brady  Kirk Cousins*
# Tm                             KAN             LAC        TAM            MIN
# Age                             27              24         45             34
# Pos                             QB              QB         QB             QB
# Games_G                         17              17         17             17
# Games_GS                        17              17         17             17
# Passing_Cmp                    435             477        490            424
# Passing_Att                    648             699        733            643
# Passing_Yds                   5250            4739       4694           4547
# Passing_IAY                   4686            4476       4876           4800
# Passing_IAY/PA                 7.2             6.4        6.7            7.5
# ...

# %%
d = d.drop(d[d['Pos'] != 'QB'].index)
d = d.drop(d[d['Passing_Yds'] < 999].index)


d
# Out:
#                Player   Tm  Age Pos  Games_G  Games_GS  Passing_Cmp  \
# 0   Patrick Mahomes*+  KAN   27  QB       17        17          435
# 1      Justin Herbert  LAC   24  QB       17        17          477
# 2           Tom Brady  TAM   45  QB       17        17          490
# 3       Kirk Cousins*  MIN   34  QB       17        17          424
# 4         Joe Burrow*  CIN   26  QB       16        16          414
# 5         Jared Goff*  DET   28  QB       17        17          382
# 6         Josh Allen*  BUF   26  QB       16        16          359
# 7         Geno Smith*  SEA   32  QB       17        17          399
# 8    Trevor Lawrence*  JAX   23  QB       17        17          387
# 9        Jalen Hurts*  PHI   24  QB       15        15          306
# 10      Aaron Rodgers  GNB   39  QB       17        17          350
# 11     Tua Tagovailoa  MIA   24  QB       13        13          259
# 12     Russell Wilson  DEN   34  QB       15        15          292
# ...

# %%
min_yds = d['Passing_Yds'].min()

min_yds
# Out:
# 1051

# %%
std_yds = d['Passing_Yds'].std()



std_yds
# Out:
# 1208.4553853384807

# %%
mean_yds = d['Passing_Yds'].mean()

mean_yds
# Out:
# 2859.7179487179487

# %%
fig, ax = plt.subplots(1, 1)

x = d['Passing_Att']

y = d['Passing_Cmp']

rv = binom(x, y)
plt.show()
